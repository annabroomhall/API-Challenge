# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import weather_api_key
from pprint import pprint
from citipy import citipy
import random as rd

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
city_lat = 29.951065
city_long = -90.071533

nearest_city = citipy.nearest_city(city_lat, city_long)

cities = nearest_city.city_name
cities
# Out:
# 'new orleans'

# %%
response = requests.get(query_url + 'new orleans').json()

pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 29.9547, 'lon': -90.0751},
#  'dt': 1615878962,
#  'id': 4335045,
#  'main': {'feels_like': 75.67,
#           'humidity': 94,
#           'pressure': 1015,
#           'temp': 71.89,
#           'temp_max': 73.99,
#           'temp_min': 70},
#  'name': 'New Orleans',
#  'sys': {'country': 'US',
#          'id': 3104,
#          'sunrise': 1615896519,
#          'sunset': 1615939747,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 6.91}}

# %%
# create a list that we'll store all our data in
city_list = []

# create a list of 1000 cities
while len(city_list) < 50:
    
    # set random lat and long
    latitude = rd.uniform(-90.0,90.0)
    longitude = rd.uniform(-180.0,180.0)
    
    # get nearest city
    city = citipy.nearest_city(latitude,longitude).city_name
        
    if city not in city_list:
        city_list.append(city)

# %%
city_list
# Out:
# ['punta arenas',
#  'albany',
#  'kaitangata',
#  'mataura',
#  'arraial do cabo',
#  'thompson',
#  'yellowknife',
#  'taolanaro',
#  'port alfred',
#  'laguna',
#  'lebu',
#  'jumla',
#  'sailana',
#  'rikitea',
#  'hauterive',
#  'sulangan',
#  'paamiut',
#  'avarua',
#  'chinhoyi',
#  'cape town',
#  'pula',
#  'butaritari',
#  'berlevag',
#  'mount gambier',
#  'yialos',
#  'matara',
#  'thunder bay',
#  'naze',
#  'illoqqortoormiut',
#  'kiruna',
#  'saint anthony',
#  'manta',
#  'ancud',
#  'inuvik',
#  'dodola',
#  'ozgon',
#  'fagersta',
#  'aklavik',
#  'khatanga',
#  'iqaluit',
#  'barrow',
#  'phuket',
#  'tiznit',
#  'tuatapere',
#  'coquimbo',
#  'benoy',
#  'ushuaia',
#  'temaraia',
#  'willmar',
#  'chuy']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up lists to hold reponse info
cities = city_list
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
name = []
number = []


# Loop through the list of cities and perform a request for data on each
for city in city_list:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        name.append(response['name'])
        number.append(response['id'])
        print(f"City: {(response['name'])} (ID: {(response['id'])}) located! Appending stats")
    except:
        print(f"{city} not found - keep running")
    #print(f"Printing data for: (response[name]) in response['country'])") - not working 

#print(f"Printing data for: {name} in {country}")
# Out:
# City: Punta Arenas (ID: 3874787) located! Appending stats
# City: Albany (ID: 5106841) located! Appending stats
# City: Kaitangata (ID: 2208248) located! Appending stats
# City: Mataura (ID: 6201424) located! Appending stats
# City: Arraial do Cabo (ID: 3471451) located! Appending stats
# City: Thompson (ID: 6165406) located! Appending stats
# City: Yellowknife (ID: 6185377) located! Appending stats
# taolanaro not found - keep running
# City: Port Alfred (ID: 964432) located! Appending stats
# City: Laguna (ID: 5364271) located! Appending stats
# City: Lebu (ID: 3883457) located! Appending stats
# City: Jumla (ID: 1283285) located! Appending stats
# City: Sailāna (ID: 1257765) located! Appending stats
# City: Rikitea (ID: 4030556) located! Appending stats
# City: Hauterive (ID: 3013748) located! Appending stats
# City: Sulangan (ID: 1685422) located! Appending stats
# City: Paamiut (ID: 3421193) located! Appending stats
# City: Avarua (ID: 4035715) located! Appending stats
# City: Chinhoyi (ID: 893697) located! Appending stats
# City: Cape Town (ID: 3369157) located! Appending stats
# City: Pula (ID: 3192224) located! Appending stats
# City: Butaritari (ID: 2110227) located! Appending stats
# City: Berlevåg (ID: 780687) located! Appending stats
# City: Mount Gambier (ID: 2156643) located! Appending stats
# yialos not found - keep running
# City: Matara (ID: 1235846) located! Appending stats
# City: Thunder Bay (ID: 6166142) located! Appending stats
# City: Naze (ID: 1855540) located! Appending stats
# illoqqortoormiut not found - keep running
# City: Kiruna (ID: 605155) located! Appending stats
# City: Saint Anthony (ID: 5044290) located! Appending stats
# City: Manta (ID: 3654410) located! Appending stats
# City: Ancud (ID: 3899695) located! Appending stats
# City: Inuvik (ID: 5983607) located! Appending stats
# City: Dodola (ID: 338726) located! Appending stats
# ozgon not found - keep running
# City: Fagersta (ID: 2715656) located! Appending stats
# City: Aklavik (ID: 5882953) located! Appending stats
# City: Khatanga (ID: 2022572) located! Appending stats
# City: Iqaluit (ID: 5983720) located! Appending stats
# City: Barrow (ID: 5880054) located! Appending stats
# City: Phuket (ID: 1151253) located! Appending stats
# City: Tiznit Province (ID: 2527087) located! Appending stats
# City: Tuatapere (ID: 2180815) located! Appending stats
# City: Coquimbo (ID: 3893629) located! Appending stats
# City: Benoy (ID: 2435508) located! Appending stats
# City: Ushuaia (ID: 3833367) located! Appending stats
# temaraia not found - keep running
# City: Willmar (ID: 5052916) located! Appending stats
# City: Chui (ID: 3443061) located! Appending stats

# %%
len(lat)
# Out:
# 45

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({
                                  "City": name,
                                  "Country": country,
                                  "City ID": number,
                                  "Lat": lat,
                                  "Long": lng,
                                  "Max Temp": max_temp,
                                  "Humidity": humidity,
                                  "Cloudiness": cloudiness,
                                  "Wind Speed": wind_speed,
                                  "Date": date
                                 })

city_data
# Out:
#                City Country  City ID      Lat      Long  Max Temp  Humidity  \
# 0      Punta Arenas      CL  3874787 -53.1500  -70.9167     37.00        87
# 1            Albany      US  5106841  42.6001  -73.9662     19.00        43
# 2        Kaitangata      NZ  2208248 -46.2817  169.8464     53.01        62
# 3           Mataura      NZ  6201424 -46.1927  168.8643     54.00        65
# 4   Arraial do Cabo      BR  3471451 -22.9661  -42.0278     76.32        86
# 5          Thompson      CA  6165406  55.7435  -97.8558     19.40        68
# 6       Yellowknife      CA  6185377  62.4560 -114.3525     -7.01        77
# 7       Port Alfred      ZA   964432 -33.5906   26.8910     71.01        81
# 8            Laguna      US  5364271  38.4210 -121.4238     42.01        81
# 9              Lebu      CL  3883457 -37.6167  -73.6500     52.75        89
# 10            Jumla      NP  1283285  29.2747   82.1838     63.77        24
# 11          Sailāna      IN  1257765  23.4667   74.9167     94.23        11
# 12          Rikitea      PF  4030556 -23.1203 -134.9692     80.44        77
# 13        Hauterive      FR  3013748  46.0901    3.4459     41.00        81
# 14         Sulangan      PH  1685422  11.1373  123.7228     83.25        72
# 15          Paamiut      GL  3421193  61.9940  -49.6678     18.95        88
# 16           Avarua      CK  4035715 -21.2078 -159.7750     78.80        89
# 17         Chinhoyi      ZW   893697 -17.3667   30.2000     71.17        77
# 18        Cape Town      ZA  3369157 -33.9258   18.4232     69.01        72
# 19             Pula      HR  3192224  44.8683   13.8481     44.60        39
# 20       Butaritari      KI  2110227   3.0707  172.7902     81.28        80
# 21         Berlevåg      NO   780687  70.8578   29.0864     26.60        68
# 22    Mount Gambier      AU  2156643 -37.8333  140.7667     66.20        59
# 23           Matara      LK  1235846   5.9485   80.5353     90.81        49
# 24      Thunder Bay      CA  6166142  48.4001  -89.3168     21.00        93
# 25             Naze      JP  1855540  28.3667  129.4833     73.40        73
# 26           Kiruna      SE   605155  67.8557   20.2251     21.20        79
# 27    Saint Anthony      US  5044290  45.0205  -93.2180     30.00        86
# 28            Manta      EC  3654410  -0.9500  -80.7333     77.00        94
# 29            Ancud      CL  3899695 -41.8697  -73.8203     51.01        81
# 30           Inuvik      CA  5983607  68.3499 -133.7218    -14.80        84
# 31           Dodola      ET   338726   6.9833   39.1833     64.36        55
# 32         Fagersta      SE  2715656  60.0042   15.7932     34.00        80
# 33          Aklavik      CA  5882953  68.2191 -135.0107    -14.80        84
# 34         Khatanga      RU  2022572  71.9667  102.5000    -30.71        93
# 35          Iqaluit      CA  5983720  63.7506  -68.5145    -23.01        62
# 36           Barrow      US  5880054  71.2906 -156.7887     -2.20        71
# 37           Phuket      TH  1151253   8.0000   98.2500     93.20        40
# 38  Tiznit Province      MA  2527087  29.5833   -9.5000     61.23        40
# 39        Tuatapere      NZ  2180815 -46.1333  167.6833     54.00        65
# 40         Coquimbo      CL  3893629 -29.9533  -71.3436     59.00        88
# 41            Benoy      TD  2435508   8.9833   16.3199     87.80        30
# 42          Ushuaia      AR  3833367 -54.8000  -68.3000     35.60        80
# 43          Willmar      US  5052916  45.1219  -95.0433     30.20        86
# 44             Chui      UY  3443061 -33.6971  -53.4616     65.25        92
#
#     Cloudiness  Wind Speed        Date
# 0            0       21.85  1615879059
# 1          100        1.57  1615878987
# 2           71       11.01  1615879104
# 3           75       15.99  1615879105
# 4            0       19.04  1615879105
# 5           20       14.97  1615879106
# 6            1        4.61  1615879107
# 7           98        1.01  1615879108
# 8            1        3.60  1615879078
# 9          100        4.88  1615879109
# 10           0        6.55  1615879110
# 11           2        5.01  1615879111
# 12           2       16.02  1615879112
# 13          90        2.30  1615879112
# 14           0        5.10  1615878864
# 15          90       13.89  1615879113
# 16          36        4.61  1615879114
# 17           6        6.96  1615879115
# 18          20       14.97  1615878829
# 19           0        8.05  1615878831
# 20         100       12.28  1615879117
# 21          75       21.85  1615879117
# 22           0       17.27  1615879118
# 23           2        6.73  1615879119
# 24           1        0.69  1615879058
# 25          75       12.66  1615879121
# 26          90        6.91  1615879122
# 27          90        4.61  1615879123
# 28          90        3.44  1615879123
# 29          90        6.91  1615878852
# 30          53        2.30  1615879125
# 31          12        8.59  1615879125
# 32           0        4.61  1615879126
# 33          96        2.30  1615879127
# 34          29        8.81  1615879128
# 35           1        6.91  1615879129
# 36           1       16.11  1615879129
# 37          20        9.22  1615879130
# 38          99        1.10  1615879101
# 39          46       15.99  1615879131
# 40           0        2.30  1615879132
# 41          96       11.32  1615879133
# 42          90       17.27  1615878931
# 43          75        8.05  1615879135
# 44          26        5.50  1615879135

# %%
city_data_clean = city_data.drop_duplicates(subset=['City'])

len(city_data_clean)
# Out:
# 45

# %%
#city_data_clean.to_csv('citydataclean.csv', index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#BROOM'S WAY OF IDENTIFYING AND DROPPING TOO HUMID CITIES
#city_data_toohumid = city_data_clean.loc[city_data_clean['Humidity'] > 100]
#city_data_toohumid
#city_data_lesshumidity = city_data_clean.loc[city_data_clean['Humidity'] <= 100]

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames = city_data_clean[city_data_clean['Humidity'] > 95].index

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
city_data_lesshumid  = city_data_clean.drop(indexNames, inplace=False)
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".


city_data_lesshumid
# Out:
#                City Country  City ID      Lat      Long  Max Temp  Humidity  \
# 0      Punta Arenas      CL  3874787 -53.1500  -70.9167     37.00        87
# 1            Albany      US  5106841  42.6001  -73.9662     19.00        43
# 2        Kaitangata      NZ  2208248 -46.2817  169.8464     53.01        62
# 3           Mataura      NZ  6201424 -46.1927  168.8643     54.00        65
# 4   Arraial do Cabo      BR  3471451 -22.9661  -42.0278     76.32        86
# 5          Thompson      CA  6165406  55.7435  -97.8558     19.40        68
# 6       Yellowknife      CA  6185377  62.4560 -114.3525     -7.01        77
# 7       Port Alfred      ZA   964432 -33.5906   26.8910     71.01        81
# 8            Laguna      US  5364271  38.4210 -121.4238     42.01        81
# 9              Lebu      CL  3883457 -37.6167  -73.6500     52.75        89
# 10            Jumla      NP  1283285  29.2747   82.1838     63.77        24
# 11          Sailāna      IN  1257765  23.4667   74.9167     94.23        11
# 12          Rikitea      PF  4030556 -23.1203 -134.9692     80.44        77
# 13        Hauterive      FR  3013748  46.0901    3.4459     41.00        81
# 14         Sulangan      PH  1685422  11.1373  123.7228     83.25        72
# 15          Paamiut      GL  3421193  61.9940  -49.6678     18.95        88
# 16           Avarua      CK  4035715 -21.2078 -159.7750     78.80        89
# 17         Chinhoyi      ZW   893697 -17.3667   30.2000     71.17        77
# 18        Cape Town      ZA  3369157 -33.9258   18.4232     69.01        72
# 19             Pula      HR  3192224  44.8683   13.8481     44.60        39
# 20       Butaritari      KI  2110227   3.0707  172.7902     81.28        80
# 21         Berlevåg      NO   780687  70.8578   29.0864     26.60        68
# 22    Mount Gambier      AU  2156643 -37.8333  140.7667     66.20        59
# 23           Matara      LK  1235846   5.9485   80.5353     90.81        49
# 24      Thunder Bay      CA  6166142  48.4001  -89.3168     21.00        93
# 25             Naze      JP  1855540  28.3667  129.4833     73.40        73
# 26           Kiruna      SE   605155  67.8557   20.2251     21.20        79
# 27    Saint Anthony      US  5044290  45.0205  -93.2180     30.00        86
# 28            Manta      EC  3654410  -0.9500  -80.7333     77.00        94
# 29            Ancud      CL  3899695 -41.8697  -73.8203     51.01        81
# 30           Inuvik      CA  5983607  68.3499 -133.7218    -14.80        84
# 31           Dodola      ET   338726   6.9833   39.1833     64.36        55
# 32         Fagersta      SE  2715656  60.0042   15.7932     34.00        80
# 33          Aklavik      CA  5882953  68.2191 -135.0107    -14.80        84
# 34         Khatanga      RU  2022572  71.9667  102.5000    -30.71        93
# 35          Iqaluit      CA  5983720  63.7506  -68.5145    -23.01        62
# 36           Barrow      US  5880054  71.2906 -156.7887     -2.20        71
# 37           Phuket      TH  1151253   8.0000   98.2500     93.20        40
# 38  Tiznit Province      MA  2527087  29.5833   -9.5000     61.23        40
# 39        Tuatapere      NZ  2180815 -46.1333  167.6833     54.00        65
# 40         Coquimbo      CL  3893629 -29.9533  -71.3436     59.00        88
# 41            Benoy      TD  2435508   8.9833   16.3199     87.80        30
# 42          Ushuaia      AR  3833367 -54.8000  -68.3000     35.60        80
# 43          Willmar      US  5052916  45.1219  -95.0433     30.20        86
# 44             Chui      UY  3443061 -33.6971  -53.4616     65.25        92
#
#     Cloudiness  Wind Speed        Date
# 0            0       21.85  1615879059
# 1          100        1.57  1615878987
# 2           71       11.01  1615879104
# 3           75       15.99  1615879105
# 4            0       19.04  1615879105
# 5           20       14.97  1615879106
# 6            1        4.61  1615879107
# 7           98        1.01  1615879108
# 8            1        3.60  1615879078
# 9          100        4.88  1615879109
# 10           0        6.55  1615879110
# 11           2        5.01  1615879111
# 12           2       16.02  1615879112
# 13          90        2.30  1615879112
# 14           0        5.10  1615878864
# 15          90       13.89  1615879113
# 16          36        4.61  1615879114
# 17           6        6.96  1615879115
# 18          20       14.97  1615878829
# 19           0        8.05  1615878831
# 20         100       12.28  1615879117
# 21          75       21.85  1615879117
# 22           0       17.27  1615879118
# 23           2        6.73  1615879119
# 24           1        0.69  1615879058
# 25          75       12.66  1615879121
# 26          90        6.91  1615879122
# 27          90        4.61  1615879123
# 28          90        3.44  1615879123
# 29          90        6.91  1615878852
# 30          53        2.30  1615879125
# 31          12        8.59  1615879125
# 32           0        4.61  1615879126
# 33          96        2.30  1615879127
# 34          29        8.81  1615879128
# 35           1        6.91  1615879129
# 36           1       16.11  1615879129
# 37          20        9.22  1615879130
# 38          99        1.10  1615879101
# 39          46       15.99  1615879131
# 40           0        2.30  1615879132
# 41          96       11.32  1615879133
# 42          90       17.27  1615878931
# 43          75        8.05  1615879135
# 44          26        5.50  1615879135

# %%
type(city_data_lesshumid)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generate a scatter plot of latitude versus temperature

#set data for scatter plot
lat = city_data_lesshumid.iloc[:,3]
max_temp = city_data_lesshumid.iloc[:,5]
plt.scatter(max_temp,lat)

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.xlabel('Max Temperature')
plt.ylabel('Latitude')
plt.title("Latitude vs. Temperature on 13/03/2021")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generate a scatter plot of latitude versus humidity

#set data for scatter plot
lat = city_data.iloc[:,3]
humidity = city_data.iloc[:,6]
plt.scatter(humidity,lat)

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.title("Latitude vs. Humidity on 13/03/2021")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generate a scatter plot of latitude versus cloudiness

#set data for scatter plot
lat = city_data.iloc[:,3]
cloudiness = city_data.iloc[:,7]
plt.scatter(cloudiness,lat)

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.title("Latitude vs. Cloudiness on 13/03/2021")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generate a scatter plot of latitude versus wind speed

#set data for scatter plot
lat = city_data.iloc[:,3]
wind_speed = city_data.iloc[:,8]
plt.scatter(wind_speed,lat)

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
plt.title("Latitude vs. Wind Speed on 13/03/2021")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Data by Hemisphere

# Create the bins in which Data will be held
bins = [-90, 0, 90]

# Names for the bins
hemisphere = ["Southern Hemisphere", "Northern Hemisphere"]

# Add bins to city_data table
city_data["Hemisphere"] = pd.cut(city_data["Lat"], 
                                          bins, labels=hemisphere, include_lowest=True)

city_data_north = city_data.loc[city_data['Hemisphere'] == 'Northern Hemisphere']
city_data_south = city_data.loc[city_data['Hemisphere'] == 'Southern Hemisphere']

# %%
city_data_south.head()
# Out:
#               City Country  City ID      Lat      Long  Max Temp  Humidity  \
# 0     Punta Arenas      CL  3874787 -53.1500  -70.9167     37.00        87
# 2       Kaitangata      NZ  2208248 -46.2817  169.8464     53.01        62
# 3          Mataura      NZ  6201424 -46.1927  168.8643     54.00        65
# 4  Arraial do Cabo      BR  3471451 -22.9661  -42.0278     76.32        86
# 7      Port Alfred      ZA   964432 -33.5906   26.8910     71.01        81
#
#    Cloudiness  Wind Speed        Date           Hemisphere
# 0           0       21.85  1615879059  Southern Hemisphere
# 2          71       11.01  1615879104  Southern Hemisphere
# 3          75       15.99  1615879105  Southern Hemisphere
# 4           0       19.04  1615879105  Southern Hemisphere
# 7          98        1.01  1615879108  Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus temperature in Northern Hemisphere

#set data for scatter plot
lat = city_data_north.iloc[:,3]
max_temp = city_data_north.iloc[:,5]
plt.scatter(lat,max_temp)

nmt_slope, nmt_int, nmt_r, nmt_p, nmt_std_err = stats.linregress(lat,max_temp)
nmt_regress = lat * nmt_slope + nmt_int

#Plot linear regression
plt.plot(lat,nmt_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(nmt_slope,2)) + "x + " + str(round(nmt_int,2))
plt.annotate(line_eq,(30,60),fontsize = 15,color = "red")


#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere Temperature vs Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus temperature in Southern Hemisphere

#set data for scatter plot
lat = city_data_south.iloc[:,3]
max_temp = city_data_south.iloc[:,5]
plt.scatter(lat,max_temp)

smt_slope, smt_int, smt_r, smt_p, smt_std_err = stats.linregress(lat,max_temp)
smt_regress = lat * smt_slope + smt_int

#Plot linear regression
plt.plot(lat,smt_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(smt_slope,2)) + "x + " + str(round(smt_int,2))
plt.annotate(line_eq,(-55,65),fontsize = 15,color = "red")


#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.xlim(-60,0)
plt.title("Southern Hemisphere Temperature vs Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus humidity

#set data for scatter plot
lat = city_data_north.iloc[:,3]
humidity = city_data_north.iloc[:,6]
plt.scatter(lat, humidity)

nh_slope, nh_int, nh_r, nh_p, nh_std_err = stats.linregress(lat, humidity)
nh_regress = lat * nh_slope + nh_int

#Plot linear regression
plt.plot(lat,nh_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(nh_slope,2)) + "x + " + str(round(nh_int,2))
plt.annotate(line_eq,(60,30),fontsize = 15,color = "red")

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere Humidity vs. Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus humidity

#set data for scatter plot
lat = city_data_south.iloc[:,3]
humidity = city_data_south.iloc[:,6]
plt.scatter(lat, humidity)

sh_slope, sh_int, sh_r, sh_p, sh_std_err = stats.linregress(lat, humidity)
sh_regress = lat * sh_slope + sh_int

#Plot linear regression
plt.plot(lat,sh_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(sh_slope,2)) + "x + " + str(round(sh_int,2))
plt.annotate(line_eq,(-65,90),fontsize = 15,color = "red")

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Humidity')
plt.xlabel('Latitude')
#plt.xlim(-70,0)
plt.title("Southern Hemisphere Humidity vs. Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus cloudiness

#set data for scatter plot
lat = city_data_north.iloc[:,3]
cloudiness = city_data_north.iloc[:,7]
plt.scatter(lat, cloudiness)

nc_slope, nc_int, nc_r, nc_p, nc_std_err = stats.linregress(lat, cloudiness)
nc_regress = lat * nc_slope + nc_int

#Plot linear regression
plt.plot(lat,nc_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(nc_slope,2)) + "x + " + str(round(nc_int,2))
plt.annotate(line_eq,(60,40),fontsize = 15,color = "red")

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere Cloudiness vs Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus cloudiness

#set data for scatter plot
lat = city_data_south.iloc[:,3]
cloudiness = city_data_south.iloc[:,7]
plt.scatter(lat, cloudiness)

sc_slope, sc_int, sc_r, sc_p, sc_std_err = stats.linregress(lat, cloudiness)
sc_regress = lat * sc_slope + sc_int

#Plot linear regression
plt.plot(lat,sc_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(sc_slope,2)) + "x + " + str(round(sc_int,2))
plt.annotate(line_eq,(-10,60),fontsize = 15,color = "red")

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.xlim(-60,20)
plt.ylim(-10,110)
plt.title("Southern Hemisphere Cloudiness vs Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus Wind Speed (mph)

#set data for scatter plot
lat = city_data_north.iloc[:,3]
windspeed = city_data_north.iloc[:,8]
plt.scatter(lat, windspeed)

nws_slope, nws_int, nws_r, nws_p, nws_std_err = stats.linregress(lat, windspeed)
nws_regress = lat * nws_slope + nws_int

#Plot linear regression
plt.plot(lat,nws_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(nws_slope,2)) + "x + " + str(round(nws_int,2))
plt.annotate(line_eq,(5,25),fontsize = 15,color = "red")

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere Wind Speed (mph) vs Latitude on 13/03/2021")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of latitude versus Wind Speed (mph)

#set data for scatter plot
lat = city_data_south.iloc[:,3]
windspeed = city_data_south.iloc[:,8]
plt.scatter(lat, windspeed)

sws_slope, sws_int, sws_r, sws_p, sws_std_err = stats.linregress(lat, windspeed)
sws_regress = lat * sws_slope + sws_int

#Plot linear regression
plt.plot(lat,sws_regress,"r-",linewidth=1)

#Annotate linear regression
line_eq = "y = " + str(round(sws_slope,2)) + "x + " + str(round(sws_int,2))
plt.annotate(line_eq,(-10,30),fontsize = 15,color = "red")

#Add labels and title to scatter plot
#plt.xticks(max_temp)
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere Wind Speed (mph) vs Latitude on 13/03/2021")
plt.show()
